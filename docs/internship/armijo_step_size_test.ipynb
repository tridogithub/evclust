# %% [markdown]
# ## Testing the WECM algorithm with different values of gamma
# ### t0 = 1; t = t*gamma; gamma = 0.5, 0.4, 0.3, 0.2, 0.1

# %%
## Importing
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)
import numpy as np
from evclust.wecm_new import wecm
from evclust.utils import calculate_non_specificity
import pandas as pd
from sklearn.metrics import adjusted_rand_score
from ucimlrepo import fetch_ucirepo
from sklearn.preprocessing import LabelEncoder

# fetch dataset - IRIS
iris = fetch_ucirepo(id=53)

# data (as pandas dataframes)
X = iris.data.features
y = iris.data.targets

labels_encoder = LabelEncoder()
numeric_labels = labels_encoder.fit_transform(y['class'])
df = pd.concat([X, y], axis=1)

# %%
# Feature weighted ECM clustering
W = np.array([
    [0.07519226, 0.28935041, 0.16184003, 0.4736173],
    [0.09254051, 0.25118474, 0.4432175, 0.21305725],
    [0.22321534, 0.24617335, 0.0983041, 0.43230721]
])
c = 3
model = wecm(x=X, c=c, W=W, beta=2, alpha=1, delta=100, epsi=1e-3, ntrials=10, gamma=0.5)

# Compute the Adjusted Rand Index (ARI)
true_labels = numeric_labels
Y_betP = model['betp']
predicted_labels = np.argmax(Y_betP, axis=1)

ari = adjusted_rand_score(true_labels, predicted_labels)
print("----------Weighted ECM----------")
print(f"Jbest: {model['crit']}")
# print(f"Centers: \n {model['g']}")
# print(f"Final weights: \n{model['W']}")
# 
# print(f"Adjusted Rand Index (ARI): {ari}")
# 
# # Calculate Non-specificity
# calculate_non_specificity(model)
# Out:
# Initial weights:
#  [[0.07519226 0.28935041 0.16184003 0.4736173 ]
#  [0.09254051 0.25118474 0.4432175  0.21305725]
#  [0.22321534 0.24617335 0.0983041  0.43230721]]
# ---------Iteration #1---------
# Initial prototypes:
#  [[5.9016129  2.7483871  4.39354839 1.43387097]
#  [6.85       3.07368421 5.74210526 2.07105263]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.5, #iterations = 4, step size = 0.0625
# [1, 2.2797073857704855]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [2, 2.2403561408731156]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [3, 2.235042187500648]
# Armijo condition: gamma = 0.5, #iterations = 46, step size = 1.4210854715202004e-14
# [4, 2.2324793554837656]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [5, 2.23083583362243]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [6, 2.2296948783806183]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [7, 2.2288707634901566]
# [0.         2.22887076 2.22887076]
# ---------End Iteration #1---------
# ---------Iteration #2---------
# Initial prototypes:
#  [[6.85       3.07368421 5.74210526 2.07105263]
#  [5.006      3.418      1.464      0.244     ]
#  [5.9016129  2.7483871  4.39354839 1.43387097]]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [1, 2.0667598803051312]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [2, 2.003560814206405]
# WARNING: Armijo condition not converge - keep the old weight for the next iteration
# Armijo condition: gamma = 0.5, #iterations = 51, step size = 4.440892098500626e-16
# [3, 1.9938200011459706]
# WARNING: Armijo condition not converge - keep the old weight for the next iteration
# Armijo condition: gamma = 0.5, #iterations = 51, step size = 4.440892098500626e-16
# [4, 1.9919200452831158]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [5, 1.9914354747946457]
# [1.         1.99143547 1.99143547]
# ---------End Iteration #2---------
# ---------Iteration #3---------
# Initial prototypes:
#  [[5.006      3.418      1.464      0.244     ]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [6.85       3.07368421 5.74210526 2.07105263]]
# Armijo condition: gamma = 0.5, #iterations = 4, step size = 0.0625
# Armijo condition: gamma = 0.5, #iterations = 45, step size = 2.842170943040401e-14
# [1, 2.2600997263869878]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [2, 2.218296689513349]
# Armijo condition: gamma = 0.5, #iterations = 46, step size = 1.4210854715202004e-14
# [3, 2.2118852539569245]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [4, 2.2081281498321323]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [5, 2.205098974651145]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [6, 2.202476960819456]
# Armijo condition: gamma = 0.5, #iterations = 46, step size = 1.4210854715202004e-14
# [7, 2.2001631657476857]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [8, 2.1981014856104757]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [9, 2.196248289695616]
# Armijo condition: gamma = 0.5, #iterations = 49, step size = 1.7763568394002505e-15
# [10, 2.1945671884540014]
# Armijo condition: gamma = 0.5, #iterations = 49, step size = 1.7763568394002505e-15
# [11, 2.1930278752563046]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [12, 2.191605318979456]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [13, 2.190278894009121]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [14, 2.189031543605657]
# Armijo condition: gamma = 0.5, #iterations = 46, step size = 1.4210854715202004e-14
# [15, 2.187849063472834]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [16, 2.1867195341165884]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [17, 2.1856328967061573]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [18, 2.18458065473878]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [19, 2.1835556822613174]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [20, 2.1825521216599846]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [21, 2.181565356360974]
# [2.         2.18156536 1.99143547]
# ---------End Iteration #3---------
# ---------Iteration #4---------
# Initial prototypes:
#  [[6.85       3.07368421 5.74210526 2.07105263]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.5, #iterations = 8, step size = 0.00390625
# [1, 2.2112404711876725]
# Armijo condition: gamma = 0.5, #iterations = 46, step size = 1.4210854715202004e-14
# [2, 2.17100822145969]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [3, 2.163913201190354]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [4, 2.160178597371604]
# Armijo condition: gamma = 0.5, #iterations = 49, step size = 1.7763568394002505e-15
# [5, 2.1574546903746303]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [6, 2.155309118285299]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [7, 2.153596473397714]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [8, 2.15223077323073]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [9, 2.1511436242395843]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [10, 2.150277634283638]
# [3.         2.15027763 1.99143547]
# ---------End Iteration #4---------
# ---------Iteration #5---------
# Initial prototypes:
#  [[6.85       3.07368421 5.74210526 2.07105263]
#  [5.006      3.418      1.464      0.244     ]
#  [5.9016129  2.7483871  4.39354839 1.43387097]]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [1, 2.0667598803051312]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [2, 2.003560814206405]
# WARNING: Armijo condition not converge - keep the old weight for the next iteration
# Armijo condition: gamma = 0.5, #iterations = 51, step size = 4.440892098500626e-16
# [3, 1.9938200011459706]
# WARNING: Armijo condition not converge - keep the old weight for the next iteration
# Armijo condition: gamma = 0.5, #iterations = 51, step size = 4.440892098500626e-16
# [4, 1.9919200452831158]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [5, 1.9914354747946457]
# [4.         1.99143547 1.99143547]
# ---------End Iteration #5---------
# ---------Iteration #6---------
# Initial prototypes:
#  [[6.85384615 3.07692308 5.71538462 2.05384615]
#  [5.88360656 2.74098361 4.38852459 1.43442623]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.5, #iterations = 6, step size = 0.015625
# [1, 2.2231305877473537]
# Armijo condition: gamma = 0.5, #iterations = 49, step size = 1.7763568394002505e-15
# [2, 2.1749875355068293]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [3, 2.1665142534244217]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [4, 2.162378127259214]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [5, 2.159462495813547]
# WARNING: Armijo condition not converge - keep the old weight for the next iteration
# Armijo condition: gamma = 0.5, #iterations = 51, step size = 4.440892098500626e-16
# [6, 2.157171631844907]
# Armijo condition: gamma = 0.5, #iterations = 49, step size = 1.7763568394002505e-15
# [7, 2.1553307023043917]
# Armijo condition: gamma = 0.5, #iterations = 49, step size = 1.7763568394002505e-15
# [8, 2.1538518575496504]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [9, 2.1526678279771887]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [10, 2.151720928266358]
# [5.         2.15172093 1.99143547]
# ---------End Iteration #6---------
# ---------Iteration #7---------
# Initial prototypes:
#  [[6.85       3.07368421 5.74210526 2.07105263]
#  [5.006      3.418      1.464      0.244     ]
#  [5.9016129  2.7483871  4.39354839 1.43387097]]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [1, 2.0667598803051312]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [2, 2.003560814206405]
# WARNING: Armijo condition not converge - keep the old weight for the next iteration
# Armijo condition: gamma = 0.5, #iterations = 51, step size = 4.440892098500626e-16
# [3, 1.9938200011459706]
# WARNING: Armijo condition not converge - keep the old weight for the next iteration
# Armijo condition: gamma = 0.5, #iterations = 51, step size = 4.440892098500626e-16
# [4, 1.9919200452831158]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [5, 1.9914354747946457]
# [6.         1.99143547 1.99143547]
# ---------End Iteration #7---------
# ---------Iteration #8---------
# Initial prototypes:
#  [[5.006      3.418      1.464      0.244     ]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [6.85       3.07368421 5.74210526 2.07105263]]
# Armijo condition: gamma = 0.5, #iterations = 4, step size = 0.0625
# Armijo condition: gamma = 0.5, #iterations = 45, step size = 2.842170943040401e-14
# [1, 2.2600997263869878]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [2, 2.218296689513349]
# Armijo condition: gamma = 0.5, #iterations = 46, step size = 1.4210854715202004e-14
# [3, 2.2118852539569245]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [4, 2.2081281498321323]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [5, 2.205098974651145]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [6, 2.202476960819456]
# Armijo condition: gamma = 0.5, #iterations = 46, step size = 1.4210854715202004e-14
# [7, 2.2001631657476857]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [8, 2.1981014856104757]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [9, 2.196248289695616]
# Armijo condition: gamma = 0.5, #iterations = 49, step size = 1.7763568394002505e-15
# [10, 2.1945671884540014]
# Armijo condition: gamma = 0.5, #iterations = 49, step size = 1.7763568394002505e-15
# [11, 2.1930278752563046]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [12, 2.191605318979456]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [13, 2.190278894009121]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [14, 2.189031543605657]
# Armijo condition: gamma = 0.5, #iterations = 46, step size = 1.4210854715202004e-14
# [15, 2.187849063472834]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [16, 2.1867195341165884]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [17, 2.1856328967061573]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [18, 2.18458065473878]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [19, 2.1835556822613174]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [20, 2.1825521216599846]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [21, 2.181565356360974]
# [7.         2.18156536 1.99143547]
# ---------End Iteration #8---------
# ---------Iteration #9---------
# Initial prototypes:
#  [[6.85       3.07368421 5.74210526 2.07105263]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.5, #iterations = 8, step size = 0.00390625
# [1, 2.2112404711876725]
# Armijo condition: gamma = 0.5, #iterations = 46, step size = 1.4210854715202004e-14
# [2, 2.17100822145969]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [3, 2.163913201190354]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [4, 2.160178597371604]
# Armijo condition: gamma = 0.5, #iterations = 49, step size = 1.7763568394002505e-15
# [5, 2.1574546903746303]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [6, 2.155309118285299]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [7, 2.153596473397714]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [8, 2.15223077323073]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [9, 2.1511436242395843]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [10, 2.150277634283638]
# [8.         2.15027763 1.99143547]
# ---------End Iteration #9---------
# ---------Iteration #10---------
# Initial prototypes:
#  [[5.006      3.418      1.464      0.244     ]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [6.85       3.07368421 5.74210526 2.07105263]]
# Armijo condition: gamma = 0.5, #iterations = 4, step size = 0.0625
# Armijo condition: gamma = 0.5, #iterations = 45, step size = 2.842170943040401e-14
# [1, 2.2600997263869878]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [2, 2.218296689513349]
# Armijo condition: gamma = 0.5, #iterations = 46, step size = 1.4210854715202004e-14
# [3, 2.2118852539569245]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [4, 2.2081281498321323]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [5, 2.205098974651145]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [6, 2.202476960819456]
# Armijo condition: gamma = 0.5, #iterations = 46, step size = 1.4210854715202004e-14
# [7, 2.2001631657476857]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [8, 2.1981014856104757]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [9, 2.196248289695616]
# Armijo condition: gamma = 0.5, #iterations = 49, step size = 1.7763568394002505e-15
# [10, 2.1945671884540014]
# Armijo condition: gamma = 0.5, #iterations = 49, step size = 1.7763568394002505e-15
# [11, 2.1930278752563046]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [12, 2.191605318979456]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [13, 2.190278894009121]
# Armijo condition: gamma = 0.5, #iterations = 47, step size = 7.105427357601002e-15
# [14, 2.189031543605657]
# Armijo condition: gamma = 0.5, #iterations = 46, step size = 1.4210854715202004e-14
# [15, 2.187849063472834]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [16, 2.1867195341165884]
# Armijo condition: gamma = 0.5, #iterations = 50, step size = 8.881784197001252e-16
# [17, 2.1856328967061573]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [18, 2.18458065473878]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [19, 2.1835556822613174]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [20, 2.1825521216599846]
# Armijo condition: gamma = 0.5, #iterations = 48, step size = 3.552713678800501e-15
# [21, 2.181565356360974]
# [9.         2.18156536 1.99143547]
# ---------End Iteration #10---------
# Average J: 2.1200149453790647
# ----------Weighted ECM----------
# Jbest: 1.9914354747946457

# %%
# gamma = 0.4
W = np.array([
    [0.07519226, 0.28935041, 0.16184003, 0.4736173],
    [0.09254051, 0.25118474, 0.4432175, 0.21305725],
    [0.22321534, 0.24617335, 0.0983041, 0.43230721]
])
c = 3
model_gamma04 = wecm(x=X, c=c, W=W, beta=2, alpha=1, delta=100, epsi=1e-3, ntrials=10, gamma=0.4)

# Compute the Adjusted Rand Index (ARI)
true_labels = numeric_labels
Y_betP = model_gamma04['betp']
predicted_labels = np.argmax(Y_betP, axis=1)

ari = adjusted_rand_score(true_labels, predicted_labels)
print("----------Weighted ECM----------")
print(f"Jbest: {model_gamma04['crit']}")
# print(f"Centers: \n {model_gamma04['g']}")
# print(f"Final weights: \n{model_gamma04['W']}")
# 
# print(f"Adjusted Rand Index (ARI): {ari}")
# 
# # Calculate Non-specificity
# calculate_non_specificity(model_gamma04)
# Out:
# Initial weights:
#  [[0.07519226 0.28935041 0.16184003 0.4736173 ]
#  [0.09254051 0.25118474 0.4432175  0.21305725]
#  [0.22321534 0.24617335 0.0983041  0.43230721]]
# ---------Iteration #1---------
# Initial prototypes:
#  [[5.006      3.418      1.464      0.244     ]
#  [6.85       3.07368421 5.74210526 2.07105263]
#  [5.9016129  2.7483871  4.39354839 1.43387097]]
# Armijo condition: gamma = 0.4, #iterations = 2, step size = 0.16000000000000003
# Armijo condition: gamma = 0.4, #iterations = 40, step size = 1.2089258196146318e-16
# [1, 2.305296820412312]
# Armijo condition: gamma = 0.4, #iterations = 40, step size = 1.2089258196146318e-16
# [2, 2.2640425657618866]
# Armijo condition: gamma = 0.4, #iterations = 35, step size = 1.1805916207174135e-14
# [3, 2.25770507129646]
# Armijo condition: gamma = 0.4, #iterations = 35, step size = 1.1805916207174135e-14
# [4, 2.253647820337224]
# Armijo condition: gamma = 0.4, #iterations = 35, step size = 1.1805916207174135e-14
# [5, 2.2503070824236606]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [6, 2.2473074569130675]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [7, 2.244513200657482]
# Armijo condition: gamma = 0.4, #iterations = 34, step size = 2.951479051793534e-14
# [8, 2.2418836766342856]
# Armijo condition: gamma = 0.4, #iterations = 35, step size = 1.1805916207174135e-14
# [9, 2.23942434825055]
# Armijo condition: gamma = 0.4, #iterations = 35, step size = 1.1805916207174135e-14
# [10, 2.237160508056878]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [11, 2.2351200169559022]
# Armijo condition: gamma = 0.4, #iterations = 40, step size = 1.2089258196146318e-16
# [12, 2.233322251160938]
# Armijo condition: gamma = 0.4, #iterations = 34, step size = 2.951479051793534e-14
# [13, 2.231772875005427]
# Armijo condition: gamma = 0.4, #iterations = 34, step size = 2.951479051793534e-14
# [14, 2.2304636501412496]
# Armijo condition: gamma = 0.4, #iterations = 34, step size = 2.951479051793534e-14
# [15, 2.2293755407572426]
# Armijo condition: gamma = 0.4, #iterations = 35, step size = 1.1805916207174135e-14
# [16, 2.2284830745759825]
# [0.         2.22848307 2.22848307]
# ---------End Iteration #1---------
# ---------Iteration #2---------
# Initial prototypes:
#  [[5.9016129  2.7483871  4.39354839 1.43387097]
#  [6.85       3.07368421 5.74210526 2.07105263]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.4, #iterations = 3, step size = 0.06400000000000002
# [1, 2.2797073857704855]
# Armijo condition: gamma = 0.4, #iterations = 35, step size = 1.1805916207174135e-14
# [2, 2.2404002560048415]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [3, 2.235095952744947]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [4, 2.2325349519776734]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [5, 2.230891961446285]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [6, 2.2297509626057606]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [7, 2.2289264730707115]
# [1.         2.22892647 2.22848307]
# ---------End Iteration #2---------
# ---------Iteration #3---------
# Initial prototypes:
#  [[5.006      3.418      1.464      0.244     ]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [6.85       3.07368421 5.74210526 2.07105263]]
# Armijo condition: gamma = 0.4, #iterations = 3, step size = 0.06400000000000002
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [1, 2.2600997263869878]
# Armijo condition: gamma = 0.4, #iterations = 34, step size = 2.951479051793534e-14
# [2, 2.218329098341523]
# Armijo condition: gamma = 0.4, #iterations = 35, step size = 1.1805916207174135e-14
# [3, 2.2119403235539736]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [4, 2.2081919569901176]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [5, 2.2051672971019722]
# Armijo condition: gamma = 0.4, #iterations = 38, step size = 7.555786372591448e-16
# [6, 2.2025473483739755]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [7, 2.2002339522635648]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [8, 2.1981715200964635]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [9, 2.1963167853876944]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [10, 2.1946336152754977]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [11, 2.1930918824602585]
# Armijo condition: gamma = 0.4, #iterations = 38, step size = 7.555786372591448e-16
# [12, 2.1916666808701613]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [13, 2.1903374724982907]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [14, 2.189087262633745]
# Armijo condition: gamma = 0.4, #iterations = 39, step size = 3.022314549036579e-16
# [15, 2.187901891774749]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [16, 2.18676947401754]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [17, 2.1856799774948708]
# Armijo condition: gamma = 0.4, #iterations = 42, step size = 1.934281311383411e-17
# [18, 2.1846249297262856]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [19, 2.183597228965937]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [20, 2.1825910447173187]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [21, 2.1816017927698157]
# [2.         2.18160179 2.18160179]
# ---------End Iteration #3---------
# ---------Iteration #4---------
# Initial prototypes:
#  [[5.9016129  2.7483871  4.39354839 1.43387097]
#  [6.85       3.07368421 5.74210526 2.07105263]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.4, #iterations = 3, step size = 0.06400000000000002
# [1, 2.2797073857704855]
# Armijo condition: gamma = 0.4, #iterations = 35, step size = 1.1805916207174135e-14
# [2, 2.2404002560048415]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [3, 2.235095952744947]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [4, 2.2325349519776734]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [5, 2.230891961446285]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [6, 2.2297509626057606]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [7, 2.2289264730707115]
# [3.         2.22892647 2.18160179]
# ---------End Iteration #4---------
# ---------Iteration #5---------
# Initial prototypes:
#  [[5.006      3.418      1.464      0.244     ]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [6.85       3.07368421 5.74210526 2.07105263]]
# Armijo condition: gamma = 0.4, #iterations = 3, step size = 0.06400000000000002
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [1, 2.2600997263869878]
# Armijo condition: gamma = 0.4, #iterations = 34, step size = 2.951479051793534e-14
# [2, 2.218329098341523]
# Armijo condition: gamma = 0.4, #iterations = 35, step size = 1.1805916207174135e-14
# [3, 2.2119403235539736]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [4, 2.2081919569901176]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [5, 2.2051672971019722]
# Armijo condition: gamma = 0.4, #iterations = 38, step size = 7.555786372591448e-16
# [6, 2.2025473483739755]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [7, 2.2002339522635648]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [8, 2.1981715200964635]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [9, 2.1963167853876944]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [10, 2.1946336152754977]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [11, 2.1930918824602585]
# Armijo condition: gamma = 0.4, #iterations = 38, step size = 7.555786372591448e-16
# [12, 2.1916666808701613]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [13, 2.1903374724982907]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [14, 2.189087262633745]
# Armijo condition: gamma = 0.4, #iterations = 39, step size = 3.022314549036579e-16
# [15, 2.187901891774749]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [16, 2.18676947401754]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [17, 2.1856799774948708]
# Armijo condition: gamma = 0.4, #iterations = 42, step size = 1.934281311383411e-17
# [18, 2.1846249297262856]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [19, 2.183597228965937]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [20, 2.1825910447173187]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [21, 2.1816017927698157]
# [4.         2.18160179 2.18160179]
# ---------End Iteration #5---------
# ---------Iteration #6---------
# Initial prototypes:
#  [[6.85       3.07368421 5.74210526 2.07105263]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.4, #iterations = 6, step size = 0.0040960000000000015
# [1, 2.2112404711876725]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [2, 2.1710159803009548]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [3, 2.1639249249200847]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [4, 2.1601923438865853]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [5, 2.1574697541166143]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [6, 2.1553250467063223]
# Armijo condition: gamma = 0.4, #iterations = 38, step size = 7.555786372591448e-16
# [7, 2.153612947579493]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [8, 2.1522475716040157]
# Armijo condition: gamma = 0.4, #iterations = 38, step size = 7.555786372591448e-16
# [9, 2.151160598522922]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [10, 2.1502946889999235]
# [5.         2.15029469 2.15029469]
# ---------End Iteration #6---------
# ---------Iteration #7---------
# Initial prototypes:
#  [[5.9016129  2.7483871  4.39354839 1.43387097]
#  [5.006      3.418      1.464      0.244     ]
#  [6.85       3.07368421 5.74210526 2.07105263]]
# Armijo condition: gamma = 0.4, #iterations = 38, step size = 7.555786372591448e-16
# [1, 2.1001496175998]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [2, 2.0354319257962015]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [3, 2.028095689730238]
# Armijo condition: gamma = 0.4, #iterations = 38, step size = 7.555786372591448e-16
# [4, 2.0270111024625055]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [5, 2.026785172365983]
# [6.         2.02678517 2.02678517]
# ---------End Iteration #7---------
# ---------Iteration #8---------
# Initial prototypes:
#  [[6.85384615 3.07692308 5.71538462 2.05384615]
#  [5.88360656 2.74098361 4.38852459 1.43442623]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.4, #iterations = 5, step size = 0.010240000000000004
# [1, 2.2231305877473537]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [2, 2.1747536024208745]
# Armijo condition: gamma = 0.4, #iterations = 42, step size = 1.934281311383411e-17
# [3, 2.166162641019084]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [4, 2.1619641644681664]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [5, 2.1590075197710594]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [6, 2.1566893441814265]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [7, 2.1548309376644617]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [8, 2.153341608399393]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [9, 2.152151862513042]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [10, 2.1512023558823405]
# [7.         2.15120236 2.02678517]
# ---------End Iteration #8---------
# ---------Iteration #9---------
# Initial prototypes:
#  [[5.885      2.74       4.37666667 1.41833333]
#  [6.8275     3.07       5.7        2.0625    ]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.4, #iterations = 3, step size = 0.06400000000000002
# [1, 2.29161140646604]
# Armijo condition: gamma = 0.4, #iterations = 35, step size = 1.1805916207174135e-14
# [2, 2.247559808519627]
# Armijo condition: gamma = 0.4, #iterations = 39, step size = 3.022314549036579e-16
# [3, 2.2392937599567544]
# Armijo condition: gamma = 0.4, #iterations = 38, step size = 7.555786372591448e-16
# [4, 2.235161110681088]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [5, 2.2326403596109388]
# Armijo condition: gamma = 0.4, #iterations = 35, step size = 1.1805916207174135e-14
# [6, 2.230972146165016]
# Armijo condition: gamma = 0.4, #iterations = 38, step size = 7.555786372591448e-16
# [7, 2.229809948461945]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [8, 2.228970423713484]
# [8.         2.22897042 2.02678517]
# ---------End Iteration #9---------
# ---------Iteration #10---------
# Initial prototypes:
#  [[6.85       3.07368421 5.74210526 2.07105263]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.4, #iterations = 6, step size = 0.0040960000000000015
# [1, 2.2112404711876725]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [2, 2.1710159803009548]
# Armijo condition: gamma = 0.4, #iterations = 36, step size = 4.7223664828696544e-15
# [3, 2.1639249249200847]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [4, 2.1601923438865853]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [5, 2.1574697541166143]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [6, 2.1553250467063223]
# Armijo condition: gamma = 0.4, #iterations = 38, step size = 7.555786372591448e-16
# [7, 2.153612947579493]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [8, 2.1522475716040157]
# Armijo condition: gamma = 0.4, #iterations = 38, step size = 7.555786372591448e-16
# [9, 2.151160598522922]
# Armijo condition: gamma = 0.4, #iterations = 37, step size = 1.8889465931478618e-15
# [10, 2.1502946889999235]
# [9.         2.15029469 2.02678517]
# ---------End Iteration #10---------
# Average J: 2.1757086936218695
# ----------Weighted ECM----------
# Jbest: 2.026785172365983

# %%
# gamma = 0.3
W = np.array([
    [0.07519226, 0.28935041, 0.16184003, 0.4736173],
    [0.09254051, 0.25118474, 0.4432175, 0.21305725],
    [0.22321534, 0.24617335, 0.0983041, 0.43230721]
])
c = 3
model_gamma03 = wecm(x=X, c=c, W=W, beta=2, alpha=1, delta=100, epsi=1e-3, ntrials=10, gamma=0.3)

# Compute the Adjusted Rand Index (ARI)
true_labels = numeric_labels
Y_betP = model_gamma03['betp']
predicted_labels = np.argmax(Y_betP, axis=1)

ari = adjusted_rand_score(true_labels, predicted_labels)
print("----------Weighted ECM----------")
print(f"Jbest: {model_gamma03['crit']}")
# Out:
# Initial weights:
#  [[0.07519226 0.28935041 0.16184003 0.4736173 ]
#  [0.09254051 0.25118474 0.4432175  0.21305725]
#  [0.22321534 0.24617335 0.0983041  0.43230721]]
# ---------Iteration #1---------
# Initial prototypes:
#  [[6.85       3.07368421 5.74210526 2.07105263]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.3, #iterations = 5, step size = 0.00243
# [1, 2.2112404711876725]
# Armijo condition: gamma = 0.3, #iterations = 28, step size = 2.2876792454960983e-15
# [2, 2.1709488721715333]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [3, 2.1638228991810378]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [4, 2.16007252278655]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [5, 2.157338349141224]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [6, 2.1551860409015338]
# Armijo condition: gamma = 0.3, #iterations = 29, step size = 6.863037736488295e-16
# [7, 2.153469146232975]
# Armijo condition: gamma = 0.3, #iterations = 28, step size = 2.2876792454960983e-15
# [8, 2.152100922384093]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [9, 2.151012404013744]
# Armijo condition: gamma = 0.3, #iterations = 28, step size = 2.2876792454960983e-15
# [10, 2.1501457874105903]
# [0.         2.15014579 2.15014579]
# ---------End Iteration #1---------
# ---------Iteration #2---------
# Initial prototypes:
#  [[5.006      3.418      1.464      0.244     ]
#  [6.8275     3.07       5.7        2.0625    ]
#  [5.885      2.74       4.37666667 1.41833333]]
# Armijo condition: gamma = 0.3, #iterations = 2, step size = 0.09
# Armijo condition: gamma = 0.3, #iterations = 3, step size = 0.027
# [1, 2.3186503241550884]
# Armijo condition: gamma = 0.3, #iterations = 4, step size = 0.0081
# [2, 2.2721331119702017]
# Armijo condition: gamma = 0.3, #iterations = 5, step size = 0.00243
# [3, 2.263000090618053]
# Armijo condition: gamma = 0.3, #iterations = 25, step size = 8.472886094429994e-14
# [4, 2.257693495590503]
# Armijo condition: gamma = 0.3, #iterations = 25, step size = 8.472886094429994e-14
# [5, 2.2537349090007797]
# Armijo condition: gamma = 0.3, #iterations = 25, step size = 8.472886094429994e-14
# [6, 2.2504160361470253]
# Armijo condition: gamma = 0.3, #iterations = 25, step size = 8.472886094429994e-14
# [7, 2.247441666027302]
# Armijo condition: gamma = 0.3, #iterations = 23, step size = 9.414317882699993e-13
# [8, 2.2446851891489272]
# Armijo condition: gamma = 0.3, #iterations = 6, step size = 0.0007289999999999999
# [9, 2.242103208194782]
# Armijo condition: gamma = 0.3, #iterations = 6, step size = 0.0007289999999999999
# [10, 2.2396942419842096]
# Armijo condition: gamma = 0.3, #iterations = 5, step size = 0.00243
# [11, 2.2374757886692027]
# Armijo condition: gamma = 0.3, #iterations = 5, step size = 0.00243
# [12, 2.235467018054045]
# Armijo condition: gamma = 0.3, #iterations = 5, step size = 0.00243
# [13, 2.2336844985090125]
# Armijo condition: gamma = 0.3, #iterations = 5, step size = 0.00243
# [14, 2.2321340457640693]
# Armijo condition: gamma = 0.3, #iterations = 6, step size = 0.0007289999999999999
# [15, 2.230809948165984]
# Armijo condition: gamma = 0.3, #iterations = 5, step size = 0.00243
# [16, 2.229698817964382]
# Armijo condition: gamma = 0.3, #iterations = 5, step size = 0.00243
# [17, 2.2287765049185073]
# [1.         2.2287765  2.15014579]
# ---------End Iteration #2---------
# ---------Iteration #3---------
# Initial prototypes:
#  [[6.85       3.07368421 5.74210526 2.07105263]
#  [5.006      3.418      1.464      0.244     ]
#  [5.9016129  2.7483871  4.39354839 1.43387097]]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [1, 2.0667598803051312]
# Armijo condition: gamma = 0.3, #iterations = 29, step size = 6.863037736488295e-16
# [2, 2.0035608142064056]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [3, 1.993820001145971]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [4, 1.9919200452831163]
# Armijo condition: gamma = 0.3, #iterations = 29, step size = 6.863037736488295e-16
# [5, 1.9914354747946457]
# [2.         1.99143547 1.99143547]
# ---------End Iteration #3---------
# ---------Iteration #4---------
# Initial prototypes:
#  [[5.9016129  2.7483871  4.39354839 1.43387097]
#  [5.006      3.418      1.464      0.244     ]
#  [6.85       3.07368421 5.74210526 2.07105263]]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [1, 2.1001496175998]
# Armijo condition: gamma = 0.3, #iterations = 32, step size = 1.8530201888518395e-17
# [2, 2.035431925796201]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [3, 2.028095689730237]
# Armijo condition: gamma = 0.3, #iterations = 28, step size = 2.2876792454960983e-15
# [4, 2.0270111024625046]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [5, 2.0267851723659827]
# [3.         2.02678517 1.99143547]
# ---------End Iteration #4---------
# ---------Iteration #5---------
# Initial prototypes:
#  [[6.85       3.07368421 5.74210526 2.07105263]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.3, #iterations = 5, step size = 0.00243
# [1, 2.2112404711876725]
# Armijo condition: gamma = 0.3, #iterations = 28, step size = 2.2876792454960983e-15
# [2, 2.1709488721715333]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [3, 2.1638228991810378]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [4, 2.16007252278655]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [5, 2.157338349141224]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [6, 2.1551860409015338]
# Armijo condition: gamma = 0.3, #iterations = 29, step size = 6.863037736488295e-16
# [7, 2.153469146232975]
# Armijo condition: gamma = 0.3, #iterations = 28, step size = 2.2876792454960983e-15
# [8, 2.152100922384093]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [9, 2.151012404013744]
# Armijo condition: gamma = 0.3, #iterations = 28, step size = 2.2876792454960983e-15
# [10, 2.1501457874105903]
# [4.         2.15014579 1.99143547]
# ---------End Iteration #5---------
# ---------Iteration #6---------
# Initial prototypes:
#  [[5.9016129  2.7483871  4.39354839 1.43387097]
#  [6.85       3.07368421 5.74210526 2.07105263]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.3, #iterations = 3, step size = 0.027
# [1, 2.2797073857704855]
# Armijo condition: gamma = 0.3, #iterations = 8, step size = 6.560999999999999e-05
# [2, 2.2398427559281306]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [3, 2.23426247157017]
# Armijo condition: gamma = 0.3, #iterations = 26, step size = 2.541865828328998e-14
# [4, 2.231649771531863]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [5, 2.229989284033991]
# Armijo condition: gamma = 0.3, #iterations = 26, step size = 2.541865828328998e-14
# [6, 2.228845818877924]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [7, 2.2280275061923973]
# [5.         2.22802751 1.99143547]
# ---------End Iteration #6---------
# ---------Iteration #7---------
# Initial prototypes:
#  [[6.85       3.07368421 5.74210526 2.07105263]
#  [5.006      3.418      1.464      0.244     ]
#  [5.9016129  2.7483871  4.39354839 1.43387097]]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [1, 2.0667598803051312]
# Armijo condition: gamma = 0.3, #iterations = 29, step size = 6.863037736488295e-16
# [2, 2.0035608142064056]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [3, 1.993820001145971]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [4, 1.9919200452831163]
# Armijo condition: gamma = 0.3, #iterations = 29, step size = 6.863037736488295e-16
# [5, 1.9914354747946457]
# [6.         1.99143547 1.99143547]
# ---------End Iteration #7---------
# ---------Iteration #8---------
# Initial prototypes:
#  [[6.85384615 3.07692308 5.71538462 2.05384615]
#  [5.88360656 2.74098361 4.38852459 1.43442623]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.3, #iterations = 4, step size = 0.0081
# [1, 2.2231305877473537]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [2, 2.1746672856316316]
# Armijo condition: gamma = 0.3, #iterations = 28, step size = 2.2876792454960983e-15
# [3, 2.166028869208689]
# Armijo condition: gamma = 0.3, #iterations = 28, step size = 2.2876792454960983e-15
# [4, 2.161805364898571]
# Armijo condition: gamma = 0.3, #iterations = 28, step size = 2.2876792454960983e-15
# [5, 2.158832286658127]
# Armijo condition: gamma = 0.3, #iterations = 28, step size = 2.2876792454960983e-15
# [6, 2.1565031925744345]
# Armijo condition: gamma = 0.3, #iterations = 32, step size = 1.8530201888518395e-17
# [7, 2.154637815126826]
# Armijo condition: gamma = 0.3, #iterations = 28, step size = 2.2876792454960983e-15
# [8, 2.153144311781943]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [9, 2.151952292155742]
# Armijo condition: gamma = 0.3, #iterations = 28, step size = 2.2876792454960983e-15
# [10, 2.151001746770463]
# [7.         2.15100175 1.99143547]
# ---------End Iteration #8---------
# ---------Iteration #9---------
# Initial prototypes:
#  [[5.006      3.418      1.464      0.244     ]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [6.85       3.07368421 5.74210526 2.07105263]]
# Armijo condition: gamma = 0.3, #iterations = 2, step size = 0.09
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [1, 2.2600997263869878]
# Armijo condition: gamma = 0.3, #iterations = 29, step size = 6.863037736488295e-16
# [2, 2.2191559586181215]
# Armijo condition: gamma = 0.3, #iterations = 29, step size = 6.863037736488295e-16
# [3, 2.213139585058636]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [4, 2.2095396164123486]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [5, 2.206592698249749]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [6, 2.2040087780746696]
# Armijo condition: gamma = 0.3, #iterations = 28, step size = 2.2876792454960983e-15
# [7, 2.2017025957007554]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [8, 2.1996271622107324]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [9, 2.197745403093368]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [10, 2.196025628156708]
# Armijo condition: gamma = 0.3, #iterations = 29, step size = 6.863037736488295e-16
# [11, 2.1944408678295733]
# Armijo condition: gamma = 0.3, #iterations = 28, step size = 2.2876792454960983e-15
# [12, 2.1929684560578115]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [13, 2.191589452239995]
# Armijo condition: gamma = 0.3, #iterations = 29, step size = 6.863037736488295e-16
# [14, 2.1902880144167183]
# Armijo condition: gamma = 0.3, #iterations = 28, step size = 2.2876792454960983e-15
# [15, 2.189050833017715]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [16, 2.187866673692982]
# Armijo condition: gamma = 0.3, #iterations = 28, step size = 2.2876792454960983e-15
# [17, 2.18672603852377]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [18, 2.185620937398457]
# Armijo condition: gamma = 0.3, #iterations = 30, step size = 2.0589113209464885e-16
# [19, 2.1845447557173614]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [20, 2.183492203622166]
# Armijo condition: gamma = 0.3, #iterations = 31, step size = 6.176733962839465e-17
# [21, 2.182459331504963]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [22, 2.1814435945142314]
# Armijo condition: gamma = 0.3, #iterations = 29, step size = 6.863037736488295e-16
# [23, 2.180443944291977]
# [8.         2.18044394 1.99143547]
# ---------End Iteration #9---------
# ---------Iteration #10---------
# Initial prototypes:
#  [[5.9016129  2.7483871  4.39354839 1.43387097]
#  [6.85       3.07368421 5.74210526 2.07105263]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.3, #iterations = 3, step size = 0.027
# [1, 2.2797073857704855]
# Armijo condition: gamma = 0.3, #iterations = 8, step size = 6.560999999999999e-05
# [2, 2.2398427559281306]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [3, 2.23426247157017]
# Armijo condition: gamma = 0.3, #iterations = 26, step size = 2.541865828328998e-14
# [4, 2.231649771531863]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [5, 2.229989284033991]
# Armijo condition: gamma = 0.3, #iterations = 26, step size = 2.541865828328998e-14
# [6, 2.228845818877924]
# Armijo condition: gamma = 0.3, #iterations = 27, step size = 7.625597484986994e-15
# [7, 2.2280275061923973]
# [9.         2.22802751 1.99143547]
# ---------End Iteration #10---------
# Average J: 2.1326224905142195
# ----------Weighted ECM----------
# Jbest: 1.9914354747946457

# %%
# gamma = 0.2
W = np.array([
    [0.07519226, 0.28935041, 0.16184003, 0.4736173],
    [0.09254051, 0.25118474, 0.4432175, 0.21305725],
    [0.22321534, 0.24617335, 0.0983041, 0.43230721]
])
c = 3
model_gamma02 = wecm(x=X, c=c, W=W, beta=2, alpha=1, delta=100, epsi=1e-3, ntrials=10, gamma=0.2)

# Compute the Adjusted Rand Index (ARI)
true_labels = numeric_labels
Y_betP = model_gamma02['betp']
predicted_labels = np.argmax(Y_betP, axis=1)

ari = adjusted_rand_score(true_labels, predicted_labels)
print("----------Weighted ECM----------")
print(f"Jbest: {model_gamma02['crit']}")
# Out:
# Initial weights:
#  [[0.07519226 0.28935041 0.16184003 0.4736173 ]
#  [0.09254051 0.25118474 0.4432175  0.21305725]
#  [0.22321534 0.24617335 0.0983041  0.43230721]]
# ---------Iteration #1---------
# Initial prototypes:
#  [[5.88360656 2.74098361 4.38852459 1.43442623]
#  [6.85384615 3.07692308 5.71538462 2.05384615]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.2, #iterations = 2, step size = 0.04000000000000001
# [1, 2.2915772665559593]
# Armijo condition: gamma = 0.2, #iterations = 19, step size = 5.2428800000000056e-14
# [2, 2.2437149775732514]
# Armijo condition: gamma = 0.2, #iterations = 20, step size = 1.0485760000000012e-14
# [3, 2.2364076642486297]
# Armijo condition: gamma = 0.2, #iterations = 20, step size = 1.0485760000000012e-14
# [4, 2.2330146143434884]
# Armijo condition: gamma = 0.2, #iterations = 20, step size = 1.0485760000000012e-14
# [5, 2.230942275686787]
# Armijo condition: gamma = 0.2, #iterations = 20, step size = 1.0485760000000012e-14
# [6, 2.229559517164031]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [7, 2.228590911804309]
# [0.         2.22859091 2.22859091]
# ---------End Iteration #1---------
# ---------Iteration #2---------
# Initial prototypes:
#  [[6.85       3.07368421 5.74210526 2.07105263]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.2, #iterations = 4, step size = 0.0016000000000000005
# [1, 2.2112404711876725]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [2, 2.170916293847503]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [3, 2.1637728355039365]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [4, 2.1600135636456588]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [5, 2.157273603190007]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [6, 2.155117500664281]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [7, 2.153398213680504]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [8, 2.152028569776346]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [9, 2.150939280865325]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [10, 2.1500723112502587]
# [1.         2.15007231 2.15007231]
# ---------End Iteration #2---------
# ---------Iteration #3---------
# Initial prototypes:
#  [[5.9016129  2.7483871  4.39354839 1.43387097]
#  [5.006      3.418      1.464      0.244     ]
#  [6.85       3.07368421 5.74210526 2.07105263]]
# Armijo condition: gamma = 0.2, #iterations = 23, step size = 8.388608000000011e-17
# [1, 2.1001496175998]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [2, 2.0354319257962015]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [3, 2.0280956897302373]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [4, 2.0270111024625055]
# Armijo condition: gamma = 0.2, #iterations = 23, step size = 8.388608000000011e-17
# [5, 2.026785172365983]
# [2.         2.02678517 2.02678517]
# ---------End Iteration #3---------
# ---------Iteration #4---------
# Initial prototypes:
#  [[6.85       3.07368421 5.74210526 2.07105263]
#  [5.006      3.418      1.464      0.244     ]
#  [5.9016129  2.7483871  4.39354839 1.43387097]]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [1, 2.0667598803051312]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [2, 2.0035608142064047]
# Armijo condition: gamma = 0.2, #iterations = 24, step size = 1.6777216000000023e-17
# [3, 1.99382000114597]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [4, 1.9919200452831154]
# Armijo condition: gamma = 0.2, #iterations = 23, step size = 8.388608000000011e-17
# [5, 1.991435474794645]
# [3.         1.99143547 1.99143547]
# ---------End Iteration #4---------
# ---------Iteration #5---------
# Initial prototypes:
#  [[5.006      3.418      1.464      0.244     ]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [6.85       3.07368421 5.74210526 2.07105263]]
# Armijo condition: gamma = 0.2, #iterations = 2, step size = 0.04000000000000001
# Armijo condition: gamma = 0.2, #iterations = 3, step size = 0.008000000000000002
# [1, 2.2600997263869878]
# Armijo condition: gamma = 0.2, #iterations = 19, step size = 5.2428800000000056e-14
# [2, 2.218066986934906]
# Armijo condition: gamma = 0.2, #iterations = 20, step size = 1.0485760000000012e-14
# [3, 2.211424632701517]
# Armijo condition: gamma = 0.2, #iterations = 24, step size = 1.6777216000000023e-17
# [4, 2.20758019811499]
# Armijo condition: gamma = 0.2, #iterations = 20, step size = 1.0485760000000012e-14
# [5, 2.204506262560161]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [6, 2.201863940433747]
# Armijo condition: gamma = 0.2, #iterations = 20, step size = 1.0485760000000012e-14
# [7, 2.1995463112657805]
# Armijo condition: gamma = 0.2, #iterations = 24, step size = 1.6777216000000023e-17
# [8, 2.1974920745003]
# Armijo condition: gamma = 0.2, #iterations = 20, step size = 1.0485760000000012e-14
# [9, 2.1956539636401056]
# Armijo condition: gamma = 0.2, #iterations = 20, step size = 1.0485760000000012e-14
# [10, 2.1939930531962157]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [11, 2.192477282374633]
# Armijo condition: gamma = 0.2, #iterations = 24, step size = 1.6777216000000023e-17
# [12, 2.1910804088672213]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [13, 2.189780967230921]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [14, 2.1885613127064696]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [15, 2.1874068216016926]
# Armijo condition: gamma = 0.2, #iterations = 20, step size = 1.0485760000000012e-14
# [16, 2.1863052641781984]
# Armijo condition: gamma = 0.2, #iterations = 20, step size = 1.0485760000000012e-14
# [17, 2.185246335853537]
# Armijo condition: gamma = 0.2, #iterations = 20, step size = 1.0485760000000012e-14
# [18, 2.1842213232357484]
# Armijo condition: gamma = 0.2, #iterations = 20, step size = 1.0485760000000012e-14
# [19, 2.183222882263188]
# [4.         2.18322288 1.99143547]
# ---------End Iteration #5---------
# ---------Iteration #6---------
# Initial prototypes:
#  [[5.006      3.418      1.464      0.244     ]
#  [6.85       3.07368421 5.74210526 2.07105263]
#  [5.9016129  2.7483871  4.39354839 1.43387097]]
# Armijo condition: gamma = 0.2, #iterations = 1, step size = 0.2
# [1, 2.305296820412312]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [2, 2.265484760833694]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [3, 2.2592298983302004]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [4, 2.2551796843461562]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [5, 2.2518190501250968]
# Armijo condition: gamma = 0.2, #iterations = 23, step size = 8.388608000000011e-17
# [6, 2.2487790116416244]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [7, 2.245923136504797]
# Armijo condition: gamma = 0.2, #iterations = 20, step size = 1.0485760000000012e-14
# [8, 2.2432131769140167]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [9, 2.2406602108677]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [10, 2.2382971298208343]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [11, 2.2361597031236857]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [12, 2.2342738971994156]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [13, 2.232649602692276]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [14, 2.2312802377156005]
# Armijo condition: gamma = 0.2, #iterations = 20, step size = 1.0485760000000012e-14
# [15, 2.2301463334151843]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [16, 2.2292206800455587]
# [5.         2.22922068 1.99143547]
# ---------End Iteration #6---------
# ---------Iteration #7---------
# Initial prototypes:
#  [[6.85       3.07368421 5.74210526 2.07105263]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.2, #iterations = 4, step size = 0.0016000000000000005
# [1, 2.2112404711876725]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [2, 2.170916293847503]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [3, 2.1637728355039365]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [4, 2.1600135636456588]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [5, 2.157273603190007]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [6, 2.155117500664281]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [7, 2.153398213680504]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [8, 2.152028569776346]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [9, 2.150939280865325]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [10, 2.1500723112502587]
# [6.         2.15007231 1.99143547]
# ---------End Iteration #7---------
# ---------Iteration #8---------
# Initial prototypes:
#  [[5.006      3.418      1.464      0.244     ]
#  [5.88360656 2.74098361 4.38852459 1.43442623]
#  [6.85384615 3.07692308 5.71538462 2.05384615]]
# Armijo condition: gamma = 0.2, #iterations = 2, step size = 0.04000000000000001
# Armijo condition: gamma = 0.2, #iterations = 2, step size = 0.04000000000000001
# [1, 2.2695194439451276]
# Armijo condition: gamma = 0.2, #iterations = 23, step size = 8.388608000000011e-17
# [2, 2.2212035367109992]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [3, 2.2140761743196387]
# Armijo condition: gamma = 0.2, #iterations = 20, step size = 1.0485760000000012e-14
# [4, 2.2101419802336677]
# Armijo condition: gamma = 0.2, #iterations = 24, step size = 1.6777216000000023e-17
# [5, 2.2070064702345022]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [6, 2.2042831815820856]
# Armijo condition: gamma = 0.2, #iterations = 23, step size = 8.388608000000011e-17
# [7, 2.2018686287675076]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [8, 2.199709924936334]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [9, 2.197765755995339]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [10, 2.1960005577637927]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [11, 2.194383961863357]
# Armijo condition: gamma = 0.2, #iterations = 24, step size = 1.6777216000000023e-17
# [12, 2.1928904900852304]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [13, 2.191498958161926]
# Armijo condition: gamma = 0.2, #iterations = 23, step size = 8.388608000000011e-17
# [14, 2.19019176175543]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [15, 2.18895420474756]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [16, 2.1877739418579076]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [17, 2.1866405521359433]
# Armijo condition: gamma = 0.2, #iterations = 20, step size = 1.0485760000000012e-14
# [18, 2.1855452354118703]
# Armijo condition: gamma = 0.2, #iterations = 20, step size = 1.0485760000000012e-14
# [19, 2.184480616195602]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [20, 2.183440638915949]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [21, 2.1824205394220315]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [22, 2.1814168776171816]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [23, 2.180427613687788]
# [7.         2.18042761 1.99143547]
# ---------End Iteration #8---------
# ---------Iteration #9---------
# Initial prototypes:
#  [[6.85       3.07368421 5.74210526 2.07105263]
#  [5.006      3.418      1.464      0.244     ]
#  [5.9016129  2.7483871  4.39354839 1.43387097]]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [1, 2.0667598803051312]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [2, 2.0035608142064047]
# Armijo condition: gamma = 0.2, #iterations = 24, step size = 1.6777216000000023e-17
# [3, 1.99382000114597]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [4, 1.9919200452831154]
# Armijo condition: gamma = 0.2, #iterations = 23, step size = 8.388608000000011e-17
# [5, 1.991435474794645]
# [8.         1.99143547 1.99143547]
# ---------End Iteration #9---------
# ---------Iteration #10---------
# Initial prototypes:
#  [[5.9016129  2.7483871  4.39354839 1.43387097]
#  [5.006      3.418      1.464      0.244     ]
#  [6.85       3.07368421 5.74210526 2.07105263]]
# Armijo condition: gamma = 0.2, #iterations = 23, step size = 8.388608000000011e-17
# [1, 2.1001496175998]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [2, 2.0354319257962015]
# Armijo condition: gamma = 0.2, #iterations = 22, step size = 4.194304000000005e-16
# [3, 2.0280956897302373]
# Armijo condition: gamma = 0.2, #iterations = 21, step size = 2.0971520000000026e-15
# [4, 2.0270111024625055]
# Armijo condition: gamma = 0.2, #iterations = 23, step size = 8.388608000000011e-17
# [5, 2.026785172365983]
# [9.         2.02678517 1.99143547]
# ---------End Iteration #10---------
# Average J: 2.1158048004622616
# ----------Weighted ECM----------
# Jbest: 1.991435474794645

# %%
# gamma = 0.1
W = np.array([
    [0.07519226, 0.28935041, 0.16184003, 0.4736173],
    [0.09254051, 0.25118474, 0.4432175, 0.21305725],
    [0.22321534, 0.24617335, 0.0983041, 0.43230721]
])
c = 3
model_gamma01 = wecm(x=X, c=c, W=W, beta=2, alpha=1, delta=100, epsi=1e-3, ntrials=10, gamma=0.1)

# Compute the Adjusted Rand Index (ARI)
true_labels = numeric_labels
Y_betP = model_gamma01['betp']
predicted_labels = np.argmax(Y_betP, axis=1)

ari = adjusted_rand_score(true_labels, predicted_labels)
print("----------Weighted ECM----------")
print(f"Jbest: {model_gamma01['crit']}")
# Out:
# Initial weights:
#  [[0.07519226 0.28935041 0.16184003 0.4736173 ]
#  [0.09254051 0.25118474 0.4432175  0.21305725]
#  [0.22321534 0.24617335 0.0983041  0.43230721]]
# ---------Iteration #1---------
# Initial prototypes:
#  [[5.006      3.418      1.464      0.244     ]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [6.85       3.07368421 5.74210526 2.07105263]]
# Armijo condition: gamma = 0.1, #iterations = 1, step size = 0.1
# [1, 2.2600997263869878]
# Armijo condition: gamma = 0.1, #iterations = 14, step size = 1.0000000000000008e-14
# [2, 2.2196063850665753]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [3, 2.213723152576625]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [4, 2.210178683861845]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [5, 2.207261366095107]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [6, 2.204691399137365]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [7, 2.2023881325533217]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [8, 2.200307713482782]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [9, 2.1984153827806603]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [10, 2.1966811523941185]
# Armijo condition: gamma = 0.1, #iterations = 16, step size = 1.000000000000001e-16
# [11, 2.195079290763688]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [12, 2.1935880300656807]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [13, 2.192189085085058]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [14, 2.190867098266642]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [15, 2.1896091263067374]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [16, 2.188404222911998]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [17, 2.1872431316635246]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [18, 2.186118083760131]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [19, 2.18502268836305]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [20, 2.1839519011013278]
# Armijo condition: gamma = 0.1, #iterations = 17, step size = 1.000000000000001e-17
# [21, 2.182902054804719]
# Armijo condition: gamma = 0.1, #iterations = 17, step size = 1.000000000000001e-17
# [22, 2.1818709335348347]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [23, 2.180857865710935]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [24, 2.1798638050508354]
# [0.         2.17986381 2.17986381]
# ---------End Iteration #1---------
# ---------Iteration #2---------
# Initial prototypes:
#  [[5.88360656 2.74098361 4.38852459 1.43442623]
#  [5.006      3.418      1.464      0.244     ]
#  [6.85384615 3.07692308 5.71538462 2.05384615]]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [1, 2.1155421625765882]
# Armijo condition: gamma = 0.1, #iterations = 16, step size = 1.000000000000001e-16
# [2, 2.03784352462228]
# Armijo condition: gamma = 0.1, #iterations = 16, step size = 1.000000000000001e-16
# [3, 2.028533141438792]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [4, 2.0271333438030417]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [5, 2.0268356028726053]
# [1.        2.0268356 2.0268356]
# ---------End Iteration #2---------
# ---------Iteration #3---------
# Initial prototypes:
#  [[5.006      3.418      1.464      0.244     ]
#  [6.85       3.07368421 5.74210526 2.07105263]
#  [5.9016129  2.7483871  4.39354839 1.43387097]]
# Armijo condition: gamma = 0.1, #iterations = 1, step size = 0.1
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [1, 2.305296820412312]
# Armijo condition: gamma = 0.1, #iterations = 2, step size = 0.010000000000000002
# [2, 2.2640378404217394]
# Armijo condition: gamma = 0.1, #iterations = 2, step size = 0.010000000000000002
# [3, 2.257281485598969]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [4, 2.2531621618628437]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [5, 2.2498315300943457]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [6, 2.2468670342676185]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [7, 2.2441317092741544]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [8, 2.2415795370341387]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [9, 2.2392083315087996]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [10, 2.237034893206873]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [11, 2.2350792365885694]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [12, 2.2333548252972504]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [13, 2.2318640133527476]
# Armijo condition: gamma = 0.1, #iterations = 2, step size = 0.010000000000000002
# [14, 2.2305977687121716]
# Armijo condition: gamma = 0.1, #iterations = 4, step size = 0.00010000000000000003
# [15, 2.2295137640570357]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [16, 2.2286235931768497]
# [2.         2.22862359 2.0268356 ]
# ---------End Iteration #3---------
# ---------Iteration #4---------
# Initial prototypes:
#  [[6.85       3.07368421 5.74210526 2.07105263]
#  [5.006      3.418      1.464      0.244     ]
#  [5.9016129  2.7483871  4.39354839 1.43387097]]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [1, 2.0667598803051312]
# Armijo condition: gamma = 0.1, #iterations = 16, step size = 1.000000000000001e-16
# [2, 2.0035608142064043]
# Armijo condition: gamma = 0.1, #iterations = 16, step size = 1.000000000000001e-16
# [3, 1.9938200011459697]
# Armijo condition: gamma = 0.1, #iterations = 16, step size = 1.000000000000001e-16
# [4, 1.991920045283115]
# Armijo condition: gamma = 0.1, #iterations = 17, step size = 1.000000000000001e-17
# [5, 1.9914354747946446]
# [3.         1.99143547 1.99143547]
# ---------End Iteration #4---------
# ---------Iteration #5---------
# Initial prototypes:
#  [[6.85384615 3.07692308 5.71538462 2.05384615]
#  [5.88360656 2.74098361 4.38852459 1.43442623]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.1, #iterations = 2, step size = 0.010000000000000002
# [1, 2.2231305877473537]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [2, 2.1747437334980586]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [3, 2.1661474696263365]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [4, 2.1619461933167634]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [5, 2.1589877094333247]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [6, 2.156668311176802]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [7, 2.1548091235959466]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [8, 2.153319326422429]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [9, 2.152129325596843]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [10, 2.1511797025504236]
# [4.         2.1511797  1.99143547]
# ---------End Iteration #5---------
# ---------Iteration #6---------
# Initial prototypes:
#  [[5.006      3.418      1.464      0.244     ]
#  [6.85384615 3.07692308 5.71538462 2.05384615]
#  [5.88360656 2.74098361 4.38852459 1.43442623]]
# Armijo condition: gamma = 0.1, #iterations = 1, step size = 0.1
# Armijo condition: gamma = 0.1, #iterations = 2, step size = 0.010000000000000002
# [1, 2.318160796500182]
# Armijo condition: gamma = 0.1, #iterations = 2, step size = 0.010000000000000002
# [2, 2.268662644030378]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [3, 2.260210157158376]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [4, 2.2554342685625244]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [5, 2.2517681542544814]
# Armijo condition: gamma = 0.1, #iterations = 4, step size = 0.00010000000000000003
# [6, 2.2486183982966828]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [7, 2.2457591462768005]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [8, 2.243101294602502]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [9, 2.2406209545904883]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [10, 2.2383263914224165]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [11, 2.2362374908621394]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [12, 2.2343726686431924]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [13, 2.2327413265040343]
# Armijo condition: gamma = 0.1, #iterations = 2, step size = 0.010000000000000002
# [14, 2.23134117922467]
# Armijo condition: gamma = 0.1, #iterations = 4, step size = 0.00010000000000000003
# [15, 2.230135855009175]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [16, 2.2291368517437484]
# [5.         2.22913685 1.99143547]
# ---------End Iteration #6---------
# ---------Iteration #7---------
# Initial prototypes:
#  [[5.88360656 2.74098361 4.38852459 1.43442623]
#  [5.006      3.418      1.464      0.244     ]
#  [6.85384615 3.07692308 5.71538462 2.05384615]]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [1, 2.1155421625765882]
# Armijo condition: gamma = 0.1, #iterations = 16, step size = 1.000000000000001e-16
# [2, 2.03784352462228]
# Armijo condition: gamma = 0.1, #iterations = 16, step size = 1.000000000000001e-16
# [3, 2.028533141438792]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [4, 2.0271333438030417]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [5, 2.0268356028726053]
# [6.         2.0268356  1.99143547]
# ---------End Iteration #7---------
# ---------Iteration #8---------
# Initial prototypes:
#  [[5.9016129  2.7483871  4.39354839 1.43387097]
#  [5.006      3.418      1.464      0.244     ]
#  [6.85       3.07368421 5.74210526 2.07105263]]
# Armijo condition: gamma = 0.1, #iterations = 16, step size = 1.000000000000001e-16
# [1, 2.1001496175998]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [2, 2.0354319257962015]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [3, 2.0280956897302373]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [4, 2.027011102462505]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [5, 2.026785172365983]
# [7.         2.02678517 1.99143547]
# ---------End Iteration #8---------
# ---------Iteration #9---------
# Initial prototypes:
#  [[5.006      3.418      1.464      0.244     ]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [6.85       3.07368421 5.74210526 2.07105263]]
# Armijo condition: gamma = 0.1, #iterations = 1, step size = 0.1
# [1, 2.2600997263869878]
# Armijo condition: gamma = 0.1, #iterations = 14, step size = 1.0000000000000008e-14
# [2, 2.2196063850665753]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [3, 2.213723152576625]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [4, 2.210178683861845]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [5, 2.207261366095107]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [6, 2.204691399137365]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [7, 2.2023881325533217]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [8, 2.200307713482782]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [9, 2.1984153827806603]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [10, 2.1966811523941185]
# Armijo condition: gamma = 0.1, #iterations = 16, step size = 1.000000000000001e-16
# [11, 2.195079290763688]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [12, 2.1935880300656807]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [13, 2.192189085085058]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [14, 2.190867098266642]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [15, 2.1896091263067374]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [16, 2.188404222911998]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [17, 2.1872431316635246]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [18, 2.186118083760131]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [19, 2.18502268836305]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [20, 2.1839519011013278]
# Armijo condition: gamma = 0.1, #iterations = 17, step size = 1.000000000000001e-17
# [21, 2.182902054804719]
# Armijo condition: gamma = 0.1, #iterations = 17, step size = 1.000000000000001e-17
# [22, 2.1818709335348347]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [23, 2.180857865710935]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [24, 2.1798638050508354]
# [8.         2.17986381 1.99143547]
# ---------End Iteration #9---------
# ---------Iteration #10---------
# Initial prototypes:
#  [[6.85       3.07368421 5.74210526 2.07105263]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [5.006      3.418      1.464      0.244     ]]
# Armijo condition: gamma = 0.1, #iterations = 3, step size = 0.0010000000000000002
# [1, 2.2112404711876725]
# Armijo condition: gamma = 0.1, #iterations = 17, step size = 1.000000000000001e-17
# [2, 2.170893097601231]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [3, 2.1637369621277838]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [4, 2.159971247436476]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [5, 2.1572270972197467]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [6, 2.155068248704998]
# Armijo condition: gamma = 0.1, #iterations = 16, step size = 1.000000000000001e-16
# [7, 2.153347231020593]
# Armijo condition: gamma = 0.1, #iterations = 17, step size = 1.000000000000001e-17
# [8, 2.1519765600542358]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [9, 2.1508867138437955]
# Armijo condition: gamma = 0.1, #iterations = 15, step size = 1.0000000000000009e-15
# [10, 2.150019488729142]
# [9.         2.15001949 1.99143547]
# ---------End Iteration #10---------
# Average J: 2.1190579099207674
# ----------Weighted ECM----------
# Jbest: 1.9914354747946446
